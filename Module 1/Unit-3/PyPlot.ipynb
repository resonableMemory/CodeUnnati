# %%
import matplotlib.pyplot as plt
x = [1,2,3]
y = [2,4,1]
plt.plot(x,y)
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('My first graph!')
plt.show()

# %%
import numpy as np
x = np.arange(0,10,0.1)
y = np.sin(x)

plt.figure(figsize=(10,8))
plt.plot(x,y)
plt.show()

# %%
a = np.arange(0,10,0.1)
b = np.cos(x)

plt.figure(figsize=(10,8))
plt.plot(a,b)
plt.show()

# %%
c = np.arange(0,10,0.1)
d = np.tan(x)

plt.figure(figsize=(10,8))
plt.plot(c,d)
plt.show()

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,1,2)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])

plt.subplot(2,1,1)
plt.plot(x,y)

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6)
ax1.plot(x, y)
ax2.plot(x, -y)
ax3.plot(x, y)
ax4.plot(x, -y)
ax5.plot(x, y)
ax6.plot(x, y)

# %%
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(1,6,1)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,6,2)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,6,3)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,6,4)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,6,5)
plt.plot(x,y)

x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(1,6,6)
plt.plot(x,y)

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
from matplotlib import pyplot as plt

x = [5,2,9,4,7]
y = [10,5,8,4,2]

plt.plot(x,y)
plt.show()

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
y = [5,2,9,4,7,10,30,40,11]
x = [10,5,8,4,2,40,30,40,54]
plt.scatter(x,y)

# %%
plt.plot(x,y,'g')
plt.xlabel('x')
plt.ylabel('y')

plt.tick_params(axis='x', labelsize=18, labelrotation=-70, labelcolor='blue')
plt.tick_params(axis='y', labelsize=12, labelrotation=10, labelcolor='black')
plt.show()

# %%
y1 = [2,3,4.5]
y2 = [1,1.5,5]

plt.plot(y1)
plt.plot(y2)

plt.legend(["blue", "orange"], loc = "upper left")
plt.show()

# %%
import numpy as np
data = np.random.normal(170,10,250)

plt.hist(data)
plt.hist(data, bins=25)
plt.show()

# %%
fig, ax = plt.subplots()

x = np.linspace(0,20,1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum', xy=(6.28,1), xytext=(10,4),
           arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext = (2, -6),
           arrowprops=dict(arrowstyle="->", connectionstyle="angle3,angleA=0,angleB=-90"))
# Out:
# Text(2, -6, 'local minimum')

# %%
w = 4
h = 3
d = 70
plt.figure(figsize=(w,h), dpi=d)
plt.axis([0,5,0,5])
x = [0,3,5]
y = [1,4,3.5]
label_x = 1
label_y = 4
arrow_x = 3
arrow_y = 4

arrow_properties = dict(facecolor='black', width=0.5,headwidth = 4,shrink=0.1)

plt.annotate("maximum", xy=(arrow_x, arrow_y),
            xytext=(label_x, label_y),
            arrowprops=arrow_properties)
plt.plot(x,y)

# %%
from  mpl_toolkits import mplot3d

fig = plt.figure()

ax = plt.axes(projection = '3d')

z = np.linspace(0,1,100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)

ax.plot3D(x, y, z, 'green')
ax.set_title('3D line plot')
plt.show()

# %%
cars = ['AUDI', 'BWM', 'FORD', 'TESLA', 'JAGUAR', 'MERCEDES']

data = [23,17,35,29,12,41]

fig = plt.figure(figsize = (10,7))
plt.pie(data, labels = cars)
plt.show()
